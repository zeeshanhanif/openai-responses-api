# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
import rich

# %%
load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')
MODEL = "gpt-4o-mini"

openai = OpenAI()

# %% [markdown]
# Search the web for the latest information before generating a response
#
# 1) In Chat API model always retrieves information from web before responding to you query
# 2) In Responses API, you enable web search by configuring it in the tools, and model can choose to serach the web or not based on the content of the input prompt.

# %% [markdown]
# If you want to specify that model must call the tool, then you can use `tool_choice` parameter, and setting it to `{type: "web_search_preview"}` - this can help ensure lower latency and more consistent results.
#
# As Chat API is using specific model so it will always go for web search, this use case is relevent to Responses API

# %% [markdown]
# # Responses API

# %% [markdown]
# https://platform.openai.com/docs/guides/tools-web-search?api-mode=responses

# %%
response = openai.responses.create(
    model=MODEL,
    tools=[{
        "type": "web_search_preview",
        "user_location": {
            "type": "approximate",
            "country": "PK",
            "city": "Lahore",
            "region": "Punjab",
        }
    }],
    # input="List the best restaurants for Seafood",
    input="What is Agentic AI?",
    tool_choice={"type": "web_search_preview"} # Added tool_choice property
)

print(response.output_text)
rich.print(response.output)
rich.print(response.tools)
# rich.print(response)
# Out:
# Agentic AI refers to artificial intelligence systems that possess the capability to operate autonomously, adapt to changing environments, and make decisions aimed at achieving specific goals without continuous human intervention. These systems are characterized by their autonomy, adaptability, and context awareness, enabling them to perform complex tasks and solve problems independently. ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))
#
# **Key Features of Agentic AI:**
#
# - **Autonomy:** The ability to function independently once given an objective, reducing the need for constant human oversight. ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))
#
# - **Adaptability:** The capacity to adjust strategies or actions in response to changing conditions, ensuring the achievement of defined goals. ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))
#
# - **Context Awareness:** Understanding and interpreting environmental data to make informed decisions, enhancing the system's effectiveness in dynamic settings. ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))
#
# **Applications of Agentic AI:**
#
# Agentic AI systems are increasingly integrated into various industries to enhance efficiency and innovation:
#
# - **Business Operations:** Managing supply chains, optimizing inventory levels, forecasting demand, and planning logistics. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# - **Healthcare:** Engaging with clients, monitoring needs, executing treatment plans, and providing personalized support. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# - **Software Development:** Automatically generating debugging code, managing development lifecycles, and designing system architectures. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# - **Cybersecurity:** Monitoring network traffic, detecting issues, and responding to threats in real time. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# **Levels of Agency in AI Systems:**
#
# The degree of autonomy in AI systems varies across a spectrum:
#
# 1. **Reactive (Non-Agentic):** Responds to specific, predefined triggers or commands without independent decision-making.
#
# 2. **Assistive (Non-Agentic):** Provides recommendations or analysis but requires human intervention for final decisions and actions.
#
# 3. **Semi-Autonomous:** Performs certain tasks independently within defined parameters, with human oversight for critical decisions.
#
# 4. **Autonomous Execution:** Executes tasks autonomously without human intervention, bound by predefined rules or constraints.
#
# 5. **Autonomous Adaptability:** Adapts actions based on changing conditions and learns from past experiences to improve performance.
#
# 6. **Goal-Oriented Autonomy:** Sets and pursues long-term goals autonomously, adjusting strategies dynamically without human input.
#
# 7. **Full Agency:** Independently identifies problems, sets goals, and adapts in real time, managing all aspects of a given domain with minimal or no human oversight. ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))
#
# **Considerations and Challenges:**
#
# While agentic AI offers significant advantages, it also presents challenges:
#
# - **Security Risks:** Autonomous systems may be vulnerable to hacking or adversarial attacks, potentially leading to unintended or harmful outcomes. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# - **Unexpected Behavior:** The complexity of agentic AI can result in unpredictable actions, especially if the system's decision-making processes lack transparency. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# - **Ethical and Social Concerns:** Determining responsibility for decisions made by AI agents and addressing potential biases in their actions are critical considerations. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# In summary, agentic AI represents a significant advancement in artificial intelligence, enabling systems to perform complex tasks autonomously and adaptively. Its integration across various sectors promises enhanced efficiency and innovation, provided that associated risks are carefully managed.
# [
#     ResponseFunctionWebSearch(
#         id='ws_67df7a0f056c81928813f974735a97760dc7316d3f5e9dd6',
#         status='completed',
#         type='web_search_call'
#     ),
#     ResponseOutputMessage(
#         id='msg_67df7a11964c8192b2fbd47b345be2440dc7316d3f5e9dd6',
#         content=[
#             ResponseOutputText(
#                 annotations=[
#                     AnnotationURLCitation(
#                         end_index=469,
#                         start_index=391,
#                         title='What is Agentic AI? Definition, features, and governance considerations | KNIME',
#                         type='url_citation',
#                         url='https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=709,
#                         start_index=631,
#                         title='What is Agentic AI? Definition, features, and governance considerations | KNIME',
#                         type='url_citation',
#                         url='https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=933,
#                         start_index=855,
#                         title='What is Agentic AI? Definition, features, and governance considerations | KNIME',
#                         type='url_citation',
#                         url='https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1174,
#                         start_index=1096,
#                         title='What is Agentic AI? Definition, features, and governance considerations | KNIME',
#                         type='url_citation',
#                         url='https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1531,
#                         start_index=1443,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1743,
#                         start_index=1655,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1971,
#                         start_index=1883,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=2168,
#                         start_index=2080,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=3303,
#                         start_index=3225,
#                         title='What is Agentic AI? Definition, features, and governance considerations | KNIME',
#                         type='url_citation',
#                         url='https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=3673,
#                         start_index=3568,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=3945,
#                         start_index=3840,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=4224,
#                         start_index=4119,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     )
#                 ],
#                 text="Agentic AI refers to artificial intelligence systems that possess the capability to operate
# autonomously, adapt to changing environments, and make decisions aimed at achieving specific goals without
# continuous human intervention. These systems are characterized by their autonomy, adaptability, and context
# awareness, enabling them to perform complex tasks and solve problems independently.
# ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))\n\n**Key Features of Agentic
# AI:**\n\n- **Autonomy:** The ability to function independently once given an objective, reducing the need for
# constant human oversight. ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))\n\n-
# **Adaptability:** The capacity to adjust strategies or actions in response to changing conditions, ensuring the
# achievement of defined goals. ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))\n\n-
# **Context Awareness:** Understanding and interpreting environmental data to make informed decisions, enhancing the
# system's effectiveness in dynamic settings.
# ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))\n\n**Applications of Agentic
# AI:**\n\nAgentic AI systems are increasingly integrated into various industries to enhance efficiency and
# innovation:\n\n- **Business Operations:** Managing supply chains, optimizing inventory levels, forecasting demand,
# and planning logistics.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n- **Healthcare:**
# Engaging with clients, monitoring needs, executing treatment plans, and providing personalized support.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n- **Software
# Development:** Automatically generating debugging code, managing development lifecycles, and designing system
# architectures. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n-
# **Cybersecurity:** Monitoring network traffic, detecting issues, and responding to threats in real time.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n**Levels of Agency in
# AI Systems:**\n\nThe degree of autonomy in AI systems varies across a spectrum:\n\n1. **Reactive (Non-Agentic):**
# Responds to specific, predefined triggers or commands without independent decision-making.\n\n2. **Assistive
# (Non-Agentic):** Provides recommendations or analysis but requires human intervention for final decisions and
# actions.\n\n3. **Semi-Autonomous:** Performs certain tasks independently within defined parameters, with human
# oversight for critical decisions.\n\n4. **Autonomous Execution:** Executes tasks autonomously without human
# intervention, bound by predefined rules or constraints.\n\n5. **Autonomous Adaptability:** Adapts actions based on
# changing conditions and learns from past experiences to improve performance.\n\n6. **Goal-Oriented Autonomy:** Sets
# and pursues long-term goals autonomously, adjusting strategies dynamically without human input.\n\n7. **Full
# Agency:** Independently identifies problems, sets goals, and adapts in real time, managing all aspects of a given
# domain with minimal or no human oversight.
# ([knime.com](https://www.knime.com/blog/what-is-agentic-ai?utm_source=openai))\n\n**Considerations and
# Challenges:**\n\nWhile agentic AI offers significant advantages, it also presents challenges:\n\n- **Security
# Risks:** Autonomous systems may be vulnerable to hacking or adversarial attacks, potentially leading to unintended
# or harmful outcomes.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n-
# **Unexpected Behavior:** The complexity of agentic AI can result in unpredictable actions, especially if the
# system's decision-making processes lack transparency.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n-
# **Ethical and Social Concerns:** Determining responsibility for decisions made by AI agents and addressing
# potential biases in their actions are critical considerations.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\nIn
# summary, agentic AI represents a significant advancement in artificial intelligence, enabling systems to perform
# complex tasks autonomously and adaptively. Its integration across various sectors promises enhanced efficiency and
# innovation, provided that associated risks are carefully managed. ",
#                 type='output_text'
#             )
#         ],
#         role='assistant',
#         status='completed',
#         type='message'
#     )
# ]
# [
#     WebSearchTool(
#         type='web_search_preview',
#         search_context_size='medium',
#         user_location=UserLocation(
#             type='approximate',
#             city='Lahore',
#             country='PK',
#             region='Punjab',
#             timezone=None
#         )
#     )
# ]
